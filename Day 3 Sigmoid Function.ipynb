# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.arange(-5, 5, 0.25)
y = x*4.23 + 36.07
plt.plot(x,y)

# %%
def sigmoid(z):
    val = 1 / (1 + np.exp(-z))
    return val

# %%
plt.plot(x, sigmoid(x))
